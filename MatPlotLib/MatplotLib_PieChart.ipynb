# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# 1. Write a Python programming to create a pie chart of the popularity of programming
# Languages

# %%
Programming_languages = [ 'Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
Popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
explode = (0.1, 0, 0, 0,0,0)  
plt.pie(Popularity,labels=Programming_languages,explode=explode,shadow=True, startangle=140,autopct='%1.1f%%')
plt.axis('equal')
plt.tight_layout()

# %% [markdown]
# 2. Write a Python programming to create a pie chart with a title of the popularity of programming
# Languages.

# %%
Programming_languages = [ 'Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
Popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
explode = (0.1, 0, 0, 0,0,0)  
plt.pie(Popularity,labels=Programming_languages,explode=explode,shadow=True, startangle=140,autopct='%1.1f%%')
plt.title('Popularity od Programing Languages')
plt.axis('equal')
plt.tight_layout()

# %% [markdown]
# 3. Write a Python programming to create a pie chart with a title of the popularity of programming
# Languages.Make multiple wedges of the pie

# %%
Programming_languages = [ 'Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
Popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
explode = (0.1, 0.1, 0, 0,0,0)  
plt.pie(Popularity,labels=Programming_languages,explode=explode,shadow=True, startangle=140,autopct='%1.1f%%')
plt.title('Popularity od Programing Languages')
plt.axis('equal')
plt.tight_layout()

# %% [markdown]
# 4. Write a Python programming to create a pie chart of gold medal achievements of five most
# successful countries in 2016 Summer Olympics. Read the data from a csv file.

# %%
df = pd.read_csv('medal.csv')
print(df)
explode = (0.1, 0, 0, 0,0) 
plt.pie(df['gold_medal'],labels=df['country'],autopct='%1.1f%%',explode=explode)
plt.title('Gold Medals Won by Countries')
plt.axis('equal')
plt.tight_layout()
# Out:
#          country  gold_medal
# 0  United States          46
# 1  Great Britain          27
# 2          China          26
# 3         Russia          19
# 4        Germany          17
