# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# 1. Write a Python programming to display a bar chart of the popularity of programming
# Languages

# %%
Programming_languages = [ 'Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
Popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
plt.bar(Programming_languages,Popularity)
plt.xlabel('Programing Languages')
plt.ylabel('Popularity')
plt.title('Popularity of Programing Languages Chart')
# Out:
# Text(0.5, 1.0, 'Popularity of Programing Languages Chart')

# %% [markdown]
# 2. Write a Python programming to display a horizontal bar chart of the popularity of
# programming Languages.

# %%
Programming_languages = [ 'Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
Popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
plt.barh(Programming_languages,Popularity)
plt.xlabel('Programing Languages')
plt.ylabel('Popularity')
plt.title('Popularity of Programing Languages Chart')
# Out:
# Text(0.5, 1.0, 'Popularity of Programing Languages Chart')

# %% [markdown]
# 3. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Use uniform color.

# %%
Programming_languages = [ 'Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
Popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
plt.barh(Programming_languages,Popularity,color='r')
plt.xlabel('Programing Languages')
plt.ylabel('Popularity')
plt.title('Popularity of Programing Languages Chart')
# Out:
# Text(0.5, 1.0, 'Popularity of Programing Languages Chart')

# %% [markdown]
# 4. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Use different color for each bar

# %%
Programming_languages = [ 'Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
Popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
plt.bar(Programming_languages,Popularity,color=['r','b','k','c','g','y'])
plt.xlabel('Programing Languages')
plt.ylabel('Popularity')
plt.title('Popularity of Programing Languages Chart')
# Out:
# Text(0.5, 1.0, 'Popularity of Programing Languages Chart')

# %% [markdown]
# 5. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Attach a text label above each bar displaying its popularity

# %%
Programming_languages = [ 'Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
Popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
# plt.bar(Programming_languages,Popularity,color=['r','b','k','c','g','y'])
plt.xlabel('Programing Languages')
plt.ylabel('Popularity')
plt.title('Popularity of Programing Languages Chart')
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%f' % float(height),
        ha='center', va='bottom')
autolabel(plt.bar(Programming_languages,Popularity,color=['r','b','k','c','g','y']))
plt.axis([-1,6,0,30])
# Out:
# (-1.0, 6.0, 0.0, 30.0)

# %% [markdown]
# 6. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Make blue border to each bar.

# %%
Programming_languages = [ 'Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
Popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
axes.bar(Programming_languages,Popularity,color='r',edgecolor='b')
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# 7. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Specify the position of each bar plot

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
axes.bar([1,5,9,6,3,2],Popularity)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# 8. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Select the width of each bar and their positions.

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
axes.bar(Programming_languages,Popularity,width=[0.5,0.3,0.7,0.6,1,0.8])
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# 9. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Increase bottom margin.

# %%
Programming_languages = [ 'Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
Popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
position = [1,3,5,2,6,4]

plt.bar(Programming_languages,Popularity)
plt.xticks(rotation=90)
plt.xlabel('Programing Languages')
plt.ylabel('Popularity')
plt.title('Popularity of Programing Languages Chart')
plt.tight_layout()

# %% [markdown]
# 10. Write a Python program to create bar plot of scores by group and gender. Use multiple X
# values on the same chart for men and women.

# %%
men = np.array([22, 30, 35, 35, 26, 20])
women = np.array([25, 32, 30, 35, 29, 22])
plt.bar(np.arange(6)+0.2,men,width=0.4,label='men')
plt.bar(np.arange(6)-0.2,women,width=0.4,label='women')
plt.xticks(np.arange(6),Programming_languages)
plt.legend()
plt.tight_layout()

# %% [markdown]
# 11. Write a Python program to create bar plot from a DataFrame.

# %%
data = pd.read_csv('newdf.csv')
index = np.array([2,4,6,8,10])
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
data.set_index(index,inplace=True)
ax1.bar(index-0.6,data['a'],width=0.3)
ax1.bar(index-0.3,data['b'],width=0.3)
ax1.bar(index,data['c'],width=0.3)
ax1.bar(index+0.3,data['d'],width=0.3)
ax1.bar(index+0.6,data['e'],width=0.3)
ax1.legend(['a','b','c','d','e'])

# %% [markdown]
# 12. Write a Python program to create bar plots with error bars on the same figure

# %%
mean_v = [0.2474, 0.1235, 0.1737, 0.1824]
mean = np.array(mean_v)
sd= [0.3314, 0.2278, 0.2836, 0.2645]
index = np.arange(4)

plt.bar(index,mean,yerr=sd)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# 13. Write a Python program to create bar plots with errorbars on the same figure. Attach a text
# label above each bar displaying men means (integer value).

# %%
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x() + rect.get_width()/2., 2*height,
                '%f' % float(height),
        ha='center', va='bottom')
autolabel(plt.bar(index,mean,yerr=sd))

# %% [markdown]
# 14. Write a Python program to create a stacked bar plot with error bars.
# Note: Use bottom to stack the women?s bars on top of the men?s bars

# %%
sd_men = [4, 3, 4, 1, 5, 3]
sd_women = [3, 5, 2, 3, 3, 2]

plt.bar(np.arange(6),men,label='men',yerr=sd_men)
plt.bar(np.arange(6),women,label='women',yerr=sd_women,bottom=men)
plt.xticks(np.arange(6),Programming_languages)
plt.legend(['men','women'])
plt.tight_layout()

# %% [markdown]
# 15. Write a Python program to create a horizontal bar chart with differently ordered colors.
# Note: Use bottom to stack the women?s bars on top of the men?s bars.

# %%
languages = [['Language','Science','Math'],
['Science','Math','Language'],
['Math','Language','Science']]
numbers = [{'Language':75, 'Science':88, 'Math':96},
{'Language':71, 'Science':95, 'Math':92},
{'Language':75, 'Science':90, 'Math':89}]

df = pd.DataFrame(numbers)

plt.barh(df.index,df['Language'],)
plt.barh(df.index,df['Science'],left=df['Language'])
plt.barh(df.index,df['Math'],left=df['Science']+df['Language'])
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# 16. Write a Python program to create stack bar plot and add label to each section

# %%
plt.barh(df.index,df['Language'],label='Language')
plt.barh(df.index,df['Science'],left=df['Language'],label='Science')
plt.barh(df.index,df['Math'],left=df['Science']+df['Language'],label='Math')
# Out:
# <BarContainer object of 3 artists>

# %%
people = ('G1','G2','G3','G4','G5','G6','G7','G8')
segments = 4
data = [[ 3.40022085, 7.70632498, 6.4097905, 10.51648577, 7.5330039, 7.1123587, 12.77792868, 3.44773477],
[ 11.24811149, 5.03778215, 6.65808464, 12.32220677, 7.45964195, 6.79685302, 7.24578743, 3.69371847],
[ 3.94253354, 4.74763549, 11.73529246, 4.6465543, 12.9952182, 4.63832778, 11.16849999, 8.56883433],
[ 4.24409799, 12.71746612, 11.3772169, 9.00514257, 10.47084185, 10.97567589, 3.98287652, 8.80552122]]

df1 = pd.DataFrame(data)
df1.columns = people

plt.barh([1,2,3,4],df1['G1'])
plt.barh([1,2,3,4],df1['G2'],left=df1['G1'])
plt.barh([1,2,3,4],df1['G3'],left=df1['G1']+df1['G2'])
plt.barh([1,2,3,4],df1['G4'],left=df1['G1']+df1['G2']+df1['G3'])
plt.barh([1,2,3,4],df1['G5'],left=df1['G1']+df1['G2']+df1['G3']+df1['G4'])
plt.barh([1,2,3,4],df1['G6'],left=df1['G1']+df1['G2']+df1['G3']+df1['G4']+df1['G5'])
plt.barh([1,2,3,4],df1['G7'],left=df1['G1']+df1['G2']+df1['G3']+df1['G4']+df1['G5']+df1['G6'])
plt.barh([1,2,3,4],df1['G8'],left=df1['G1']+df1['G2']+df1['G3']+df1['G4']+df1['G5']+df1['G6']+df1['G7'])
plt.yticks([1,2,3,4])
plt.axis([-1,85,0,5])
plt.tight_layout()

# %% [markdown]
# 17. Write a Python program to add textures (black and white) to bars and wedges. Note: Use
# bottom to stack the womens bars on top of the mens bars.

# %%
sd_men = [4, 3, 4, 1, 5, 3]
sd_women = [3, 5, 2, 3, 3, 2]

plt.bar(np.arange(6),men,label='men', color='white', edgecolor='black', hatch='x')
plt.bar(np.arange(6),women,label='women', color='white', edgecolor='black', hatch='O',bottom=men)
plt.xticks(np.arange(6),Programming_languages)
plt.legend(['men','women'])
plt.tight_layout()
